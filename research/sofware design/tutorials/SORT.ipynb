# %% [markdown]
# # BUILDING THE DETECTION ENGINE

# %% [markdown]
# - install the following

# %%
# !pip install -q inference-gpu
# !pip install -q trackers
# !pip install -q supervision==0.27.0rc1
# Out:
# ^C

# %%
import cv2
from ultralytics import YOLO

model = YOLO("weights.pt")
tracker = SORTTracker()




def detection_engine():
    """our main goal here is to:
    - read frames from video source
    - run detection model on each frame
    - run SORT algorithm to track detected objects
    - emit processed frames to HMI via socket.emit()
    """
    cap = cv2.VideoCapture(0)  # video source
    while True:
        ret, frame = cap.read()
        if not ret:
            continue
        # load into YOLO model
        results = model(frame)
        detections = []

        for det in results[0].boxes.xyxy:  # xyxy format
            x1, y1, x2, y2 = det.cpu().numpy()
            conf = det.conf.cpu().numpy()
            detections.append([x1, y1, x2, y2, conf])
        tracks = tracker.update(detections)  # returns tracked objects with IDs
        for track in tracks:
            x1, y1, x2, y2, track_id = track
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0,255,0), 2)
            cv2.putText(frame, str(track_id), (x1, y1-10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0,255,0), 2)
        # here, instead of emitting directly, we would insert the frame into a thread-safe queue along with info needed by projectile prediction engine


detection_engine()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 18
#      15         if not ret:
#      16             continue
# ---> 18 detection_engine()
#
# Cell In[3], line 14, in detection_engine()
#      12 cap = cv2.VideoCapture(0)  # video source
#      13 while True:
# ---> 14     ret, frame = cap.read()
#      15     if not ret:
#      16         continue
#
# KeyboardInterrupt:

# %%
# !pip3 install ultralytics opencv-python
# Out:
# Collecting ultralytics
#   Using cached ultralytics-8.3.226-py3-none-any.whl.metadata (37 kB)
# Collecting opencv-python
#   Using cached opencv_python-4.12.0.88-cp37-abi3-macosx_13_0_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.23.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ultralytics) (2.3.3)
# Requirement already satisfied: matplotlib>=3.3.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ultralytics) (3.10.6)
# Requirement already satisfied: pillow>=7.1.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ultralytics) (11.3.0)
# Collecting pyyaml>=5.3.1 (from ultralytics)
#   Using cached pyyaml-6.0.3-cp312-cp312-macosx_10_13_x86_64.whl.metadata (2.4 kB)
# Collecting requests>=2.23.0 (from ultralytics)
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: scipy>=1.4.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ultralytics) (1.16.2)
# Collecting torch>=1.8.0 (from ultralytics)
#   Downloading torch-2.2.2-cp312-none-macosx_10_9_x86_64.whl.metadata (25 kB)
# Collecting torchvision>=0.9.0 (from ultralytics)
#   Downloading torchvision-0.17.2-cp312-cp312-macosx_10_13_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: psutil in /Users/lordskyzw/Library/Python/3.12/lib/python/site-packages (from ultralytics) (5.9.8)
# Collecting polars (from ultralytics)
#   Downloading polars-1.35.2-py3-none-any.whl.metadata (10 kB)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Downloading ultralytics_thop-2.0.18-py3-none-any.whl.metadata (14 kB)
# Collecting numpy>=1.23.0 (from ultralytics)
#   Using cached numpy-2.2.6-cp312-cp312-macosx_10_13_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/lordskyzw/Library/Python/3.12/lib/python/site-packages (from matplotlib>=3.3.0->ultralytics) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.4)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/lordskyzw/Library/Python/3.12/lib/python/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Collecting charset_normalizer<4,>=2 (from requests>=2.23.0->ultralytics)
#   Downloading charset_normalizer-3.4.4-cp312-cp312-macosx_10_13_universal2.whl.metadata (37 kB)
# Collecting idna<4,>=2.5 (from requests>=2.23.0->ultralytics)
#   Downloading idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.23.0->ultralytics)
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.23.0->ultralytics)
#   Downloading certifi-2025.10.5-py3-none-any.whl.metadata (2.5 kB)
# Collecting filelock (from torch>=1.8.0->ultralytics)
#   Downloading filelock-3.20.0-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Collecting sympy (from torch>=1.8.0->ultralytics)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch>=1.8.0->ultralytics)
#   Using cached networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch>=1.8.0->ultralytics)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec (from torch>=1.8.0->ultralytics)
#   Downloading fsspec-2025.10.0-py3-none-any.whl.metadata (10 kB)
# Collecting polars-runtime-32==1.35.2 (from polars->ultralytics)
#   Downloading polars_runtime_32-1.35.2-cp39-abi3-macosx_10_12_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: six>=1.5 in /Users/lordskyzw/Library/Python/3.12/lib/python/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Collecting MarkupSafe>=2.0 (from jinja2->torch>=1.8.0->ultralytics)
#   Using cached markupsafe-3.0.3-cp312-cp312-macosx_10_13_x86_64.whl.metadata (2.7 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->torch>=1.8.0->ultralytics)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Downloading ultralytics-8.3.226-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 590.0 kB/s eta 0:00:0000:0100:01
# Downloading opencv_python-4.12.0.88-cp37-abi3-macosx_13_0_x86_64.whl (57.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 MB 567.6 kB/s eta 0:00:0000:0100:02
# Downloading numpy-2.2.6-cp312-cp312-macosx_10_13_x86_64.whl (20.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.9/20.9 MB 402.0 kB/s eta 0:00:0000:0100:02
# Downloading pyyaml-6.0.3-cp312-cp312-macosx_10_13_x86_64.whl (182 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.1/182.1 kB 131.4 kB/s eta 0:00:00a 0:00:01
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading torch-2.2.2-cp312-none-macosx_10_9_x86_64.whl (150.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.8/150.8 MB 258.1 kB/s eta 0:00:0000:0100:08
# Downloading torchvision-0.17.2-cp312-cp312-macosx_10_13_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 455.2 kB/s eta 0:00:0000:0100:01
# Downloading ultralytics_thop-2.0.18-py3-none-any.whl (28 kB)
# Downloading polars-1.35.2-py3-none-any.whl (783 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 783.6/783.6 kB 556.4 kB/s eta 0:00:0000:0100:01
# Downloading polars_runtime_32-1.35.2-cp39-abi3-macosx_10_12_x86_64.whl (40.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 MB 1.1 MB/s eta 0:00:0000:0100:01m
# Downloading certifi-2025.10.5-py3-none-any.whl (163 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.3/163.3 kB 1.8 MB/s eta 0:00:00a 0:00:01
# Downloading charset_normalizer-3.4.4-cp312-cp312-macosx_10_13_universal2.whl (208 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.4/208.4 kB 882.2 kB/s eta 0:00:000:0100:01
# Downloading idna-3.11-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.0/71.0 kB 1.1 MB/s eta 0:00:00a 0:00:01
# Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Downloading filelock-3.20.0-py3-none-any.whl (16 kB)
# Downloading fsspec-2025.10.0-py3-none-any.whl (200 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.0/201.0 kB 9.6 MB/s eta 0:00:00
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.9/134.9 kB 1.3 MB/s eta 0:00:0000:010:01
# Downloading networkx-3.5-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 862.5 kB/s eta 0:00:0000:0100:01
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 1.4 MB/s eta 0:00:0000:0100:01m
# Downloading markupsafe-3.0.3-cp312-cp312-macosx_10_13_x86_64.whl (11 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Installing collected packages: mpmath, urllib3, sympy, pyyaml, polars-runtime-32, numpy, networkx, MarkupSafe, idna, fsspec, filelock, charset_normalizer, certifi, requests, polars, opencv-python, jinja2, torch, ultralytics-thop, torchvision, ultralytics
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.3.3
#     Uninstalling numpy-2.3.3:
#       Successfully uninstalled numpy-2.3.3
# Successfully installed MarkupSafe-3.0.3 certifi-2025.10.5 charset_normalizer-3.4.4 filelock-3.20.0 fsspec-2025.10.0 idna-3.11 jinja2-3.1.6 mpmath-1.3.0 networkx-3.5 numpy-2.2.6 opencv-python-4.12.0.88 polars-1.35.2 polars-runtime-32-1.35.2 pyyaml-6.0.3 requests-2.32.5 sympy-1.14.0 torch-2.2.2 torchvision-0.17.2 ultralytics-8.3.226 ultralytics-thop-2.0.18 urllib3-2.5.0
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: pip3 install --upgrade pip

# %%
from ultralytics import YOLO
import cv2

# Load trained model
model = YOLO("research/sofware design/resources/weights.pt")

# Load image
img = cv2.imread("research/sofware design/resources/images/example.jpeg")

# Run inference
results = model(img)

# Inspect output
print(type(results))             # usually <class 'ultralytics.engine.results.Results'>
print(dir(results[0]))           # explore attributes
print(results[0].boxes)          # bounding boxes
print(results[0].boxes.xyxy)     # xyxy coordinates
print(results[0].boxes.conf)     # confidence scores
print(results[0].boxes.cls)      # class indices
print(results[0].names)          # class name mapping

# Optional: show detections visually
annotated = results[0].plot()
cv2.imshow("Detections", annotated)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from ultralytics import YOLO
#       2 import cv2
#       4 # Load trained model
#
# ModuleNotFoundError: No module named 'ultralytics'
